# %%
 import numpy as np # linear algebra
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns

# %%
df = pd.read_csv('/content/kidney_disease.csv')

# %%
df.sample(5)
# Out:
#       id   age     bp     sg   al   su     rbc        pc         pcc  \
# 67    67  45.0   80.0  1.020  3.0  0.0  normal  abnormal  notpresent
# 18    18  60.0  100.0  1.025  0.0  3.0     NaN    normal  notpresent
# 41    41  45.0   70.0  1.010  0.0  0.0     NaN    normal  notpresent
# 197  197  57.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 27    27  69.0   70.0  1.010  3.0  4.0  normal  abnormal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 67   notpresent  ...  NaN    NaN  NaN   no   no   no  poor   no   no
# 18   notpresent  ...   37  11400  4.3  yes  yes  yes  good   no   no
# 41   notpresent  ...  NaN    NaN  NaN   no   no   no  good  yes   no
# 197  notpresent  ...  NaN   4300  3.0  yes  yes   no  good   no  yes
# 27   notpresent  ...   37   9600  4.1  yes  yes  yes  good  yes   no
#
#     classification
# 67             ckd
# 18             ckd
# 41             ckd
# 197            ckd
# 27             ckd
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df=df.iloc[:,[1,2,-1]]

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('classification',axis=1),df['classification'],test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# ### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler to the train set , it will learn the parameter
scaler.fit(x_train)

# transform train snd test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([-1.65923441e-16,  3.11354059e-17])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns= x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns= x_test.columns)

# %%
np.round(x_train.describe(),1)
# Out:
#          age     bp
# count  273.0  271.0
# mean    51.2   76.1
# std     17.8   14.2
# min      2.0   50.0
# 25%     41.0   70.0
# 50%     54.0   70.0
# 75%     65.0   80.0
# max     90.0  180.0

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          age     bp
# count  273.0  271.0
# mean    -0.0   -0.0
# std      1.0    1.0
# min     -2.8   -1.8
# 25%     -0.6   -0.4
# 50%      0.2   -0.4
# 75%      0.8    0.3
# max      2.2    7.3

# %%
x_train_scaled.head(5)
# Out:
#         age        bp
# 0  1.117081 -0.433009
# 1  1.117081  0.980791
# 2 -0.797031  1.687691
# 3 -0.065165  0.980791
# 4  0.722999 -0.433009

# %%
x_train.head(5)
# Out:
#       age     bp
# 92   71.0   70.0
# 223  71.0   90.0
# 234  37.0  100.0
# 232  50.0   90.0
# 377  64.0   70.0
